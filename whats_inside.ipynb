# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import earthaccess
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from dask.distributed import Client

# %%
# --- TIME ---

tspan = ("2024-09-01 00:00", "2025-03-01 00:00")

# --- REGION ---


mid = (21.058555012396997, 42.69174831596751)
ext = 1
region = (mid[0] - ext , mid[1] - ext, mid[0] + ext, mid[1] + ext)

results = earthaccess.search_data(
    short_name="PACE_SPEXONE_L2_AER_RTAPLAND",
    cloud_hosted=True,
    bounding_box=region,
    temporal=tspan,
)
paths = earthaccess.open(results)

dt = xr.open_datatree(paths[0])
# Out:
# QUEUEING TASKS | :   0%|          | 0/33 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/33 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/33 [00:00<?, ?it/s]
# An exception occurred while trying to access remote files via HTTPS
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/aiohttp/connector.py", line 1122, in _wrap_create_connection
#     return await self._loop.create_connection(*args, **kwargs, sock=sock)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.11/asyncio/base_events.py", line 1113, in create_connection
#     transport, protocol = await self._create_connection_transport(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.11/asyncio/base_events.py", line 1146, in _create_connection_transport
#     await waiter
# ...

# %%
# --- TIME ---

tspan = ("2024-09-01 00:00", "2025-03-01 00:00")

# --- REGION ---


mid = (21.058555012396997, 42.69174831596751)
ext = 1
region = (mid[0] - ext , mid[1] - ext, mid[0] + ext, mid[1] + ext)

results = earthaccess.search_data(
    short_name="PACE_SPEXONE_L2_AER_RTAPLAND",
    cloud_hosted=True,
    bounding_box=region,
    temporal=tspan,
)
paths = earthaccess.open(results)

dt = xr.open_datatree(paths[0])
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes: (12/32)
# │       Conventions:                       CF-1.10
# │       Metadata_Conventions:              CF-1.10
# │       creator_email:                     data@oceancolor.gsfc.nasa.gov
# │       creator_name:                      NASA/GSFC
# │       creator_url:                       http://oceancolor.gsfc.nasa.gov
# │       data_type:                         L2 Retrieval
# │       ...                                ...
# │       time_coverage_end:                 2024-09-01T11:06:54Z
# │       id:                                L2/PACE_SPEXONE.20240901T110154.L2.RTA...
# │       product_name:                      PACE_SPEXONE.20240901T110154.L2.RTAP_L...
# │       processing_version:                3.0
# │       history:                           /home/sdpsoper/Science/OCSSW/DEVEL/bin...
# │       date_created:                      2025-06-24T23:19:07.498 00:00
# ├── Group: /processing_control
# ...

# %% [markdown]
# 'quality_flag' is defined in 'diagnostic_data' . A value of 0 means perfect data
